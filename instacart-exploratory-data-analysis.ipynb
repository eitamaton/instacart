# %% [markdown]
# # Instacart: Exploratory Data Analysis

# %% [markdown]
# The dataset may be downloaded from [Kaggle](https://www.kaggle.com/c/6644/download-all) (login required).

# %% [markdown]
# Much of the credit for this notebook is due to [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart) and [Exploratory Analysis - Instacart](https://www.kaggle.com/philippsp/exploratory-analysis-instacart), both of which the author viewed prior to beginning the project.

# %% [markdown]
# ## Data Wrangling

# %%
import pandas as pd
pd.options.display.latex.repr=True

# %% [markdown]
# #### Read in the data and create DataFrames from each .csv file

# %%
file_path = 'instacart_data/all/'

df_aisles = pd.read_csv(file_path + 'aisles.csv')
df_departments = pd.read_csv(file_path + 'departments.csv')
df_order_products_prior = pd.read_csv(file_path + 'order_products__prior.csv')
df_order_products_train = pd.read_csv(file_path + 'order_products__train.csv')
df_orders = pd.read_csv(file_path + 'orders.csv')
df_products = pd.read_csv(file_path + 'products.csv')

# %% [markdown]
# #### Take a quick look at each DataFrame

# %%
df_aisles.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
df_aisles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
# aisle_id    134 non-null int64
# aisle       134 non-null object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
df_departments.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
df_departments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
# department_id    21 non-null int64
# department       21 non-null object
# dtypes: int64(1), object(1)
# memory usage: 416.0+ bytes

# %%
df_order_products_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_order_products_prior.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 4 columns):
# order_id             int64
# product_id           int64
# add_to_cart_order    int64
# reordered            int64
# dtypes: int64(4)
# memory usage: 989.8 MB

# %%
df_order_products_train.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
df_order_products_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1384617 entries, 0 to 1384616
# Data columns (total 4 columns):
# order_id             1384617 non-null int64
# product_id           1384617 non-null int64
# add_to_cart_order    1384617 non-null int64
# reordered            1384617 non-null int64
# dtypes: int64(4)
# memory usage: 42.3 MB

# %%
df_orders.head(50)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
# ...

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
# order_id                  int64
# user_id                   int64
# eval_set                  object
# order_number              int64
# order_dow                 int64
# order_hour_of_day         int64
# days_since_prior_order    float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB

# %%
df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49688 entries, 0 to 49687
# Data columns (total 4 columns):
# product_id       49688 non-null int64
# product_name     49688 non-null object
# aisle_id         49688 non-null int64
# department_id    49688 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# #### Concatenate and merge into a single DataFrame

# %%
df_order_products = pd.concat([df_order_products_prior, df_order_products_train])

# %%
df_order_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33819106 entries, 0 to 1384616
# Data columns (total 4 columns):
# order_id             int64
# product_id           int64
# add_to_cart_order    int64
# reordered            int64
# dtypes: int64(4)
# memory usage: 1.3 GB

# %% [markdown]
# Note that there are **33819106** entries. This is the total number of items ordered.

# %%
df_order_products.count()
# Out:
# order_id             33819106
# product_id           33819106
# add_to_cart_order    33819106
# reordered            33819106
# dtype: int64

# %%
# Make a separate DataFrame for the test set, since test order items are not included in df_order_products_*.

df_orders_test = df_orders[df_orders['eval_set'] == 'test']

# %%
df_orders_test.head()
# Out:
#      order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 38    2774568        3     test            13          5                 15
# 44     329954        4     test             6          3                 12
# 53    1528013        6     test             4          3                 16
# 96    1376945       11     test             8          6                 11
# 102   1356845       12     test             6          1                 20
#
#      days_since_prior_order
# 38                     11.0
# 44                     30.0
# 53                     22.0
# 96                      8.0
# 102                    30.0

# %%
df = pd.merge(df_orders, df_order_products, on='order_id')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33819106 entries, 0 to 33819105
# Data columns (total 10 columns):
# order_id                  int64
# user_id                   int64
# eval_set                  object
# order_number              int64
# order_dow                 int64
# order_hour_of_day         int64
# days_since_prior_order    float64
# product_id                int64
# add_to_cart_order         int64
# reordered                 int64
# dtypes: float64(1), int64(8), object(1)
# memory usage: 2.8+ GB

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0

# %%
d = pd.merge(df, df_products, on='product_id')
d = pd.merge(d, df_aisles, on='aisle_id')
d = pd.merge(d, df_departments, on='department_id')

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33819106 entries, 0 to 33819105
# Data columns (total 15 columns):
# order_id                  int64
# user_id                   int64
# eval_set                  object
# order_number              int64
# order_dow                 int64
# order_hour_of_day         int64
# days_since_prior_order    float64
# product_id                int64
# add_to_cart_order         int64
# reordered                 int64
# product_name              object
# aisle_id                  int64
# department_id             int64
# aisle                     object
# department                object
# dtypes: float64(1), int64(10), object(4)
# memory usage: 4.0+ GB

# %% [markdown]
# Note that there are **33819106** entries.

# %%
d.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id        aisle department
# ...

# %% [markdown]
# #### Create a MultiIndex for the combined DataFrame: ('user_id', 'order_number', 'add_to_cart_order') uniquely specifies rows.

# %%
d = d.set_index(['user_id', 'order_number', 'add_to_cart_order'])

# %%
d = d.sort_index()

# %%
d.head(100)
# Out:
#                                         order_id eval_set  order_dow  \
# user_id order_number add_to_cart_order
# 1       1            1                   2539329    prior          2
#                      2                   2539329    prior          2
#                      3                   2539329    prior          2
#                      4                   2539329    prior          2
#                      5                   2539329    prior          2
#         2            1                   2398795    prior          3
#                      2                   2398795    prior          3
#                      3                   2398795    prior          3
#                      4                   2398795    prior          3
#                      5                   2398795    prior          3
#                      6                   2398795    prior          3
#         3            1                    473747    prior          3
# ...

# %%
d.count()
# Out:
# order_id                  33819106
# eval_set                  33819106
# order_dow                 33819106
# order_hour_of_day         33819106
# days_since_prior_order    31741038
# product_id                33819106
# reordered                 33819106
# product_name              33819106
# aisle_id                  33819106
# department_id             33819106
# aisle                     33819106
# department                33819106
# dtype: int64

# %% [markdown]
# Note that all columns have **33819106** entries except 'days_since_prior_order'. Since 'days_since_prior_order' is NaN when 'order_number' is 1, we should verify that 'days_since_prior_order' is NaN *only* when 'order_number' is 1. More precisely, below we verify that it is never the case that 'days_since_prior_order' is NaN while 'order_number' is not 1:

# %%
(pd.isna(d.days_since_prior_order) & (d.index.get_level_values('order_number') != 1)).value_counts()
# Out:
# False    33819106
# Name: days_since_prior_order, dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import math
import scipy.stats as stats

# %% [markdown]
# ### Check Eval Sets

# %% [markdown]
# #### How many orders, items, and users are in each eval set?

# %%
cnt_eval_set_orders = df_orders.eval_set.value_counts()

sns.barplot(cnt_eval_set_orders.index, cnt_eval_set_orders.values)

plt.ylabel('Number of Orders')
plt.xlabel('Eval Set Type')
plt.title('Count of Orders in Each Dataset')
plt.show()

# %%
cnt_eval_set_items = d.eval_set.value_counts()

sns.barplot(cnt_eval_set_items.index, cnt_eval_set_items.values)

plt.ylabel('Number of Items')
plt.xlabel('Eval Set Type')
plt.title('Count of Items in Each Dataset')
plt.show()

# %% [markdown]
# As one would expect, an order_id with eval_set == 'test' will not appear in df_order_products with any items:

# %%
df_orders[df_orders.eval_set == 'test'].head()
# Out:
#      order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 38    2774568        3     test            13          5                 15
# 44     329954        4     test             6          3                 12
# 53    1528013        6     test             4          3                 16
# 96    1376945       11     test             8          6                 11
# 102   1356845       12     test             6          1                 20
#
#      days_since_prior_order
# 38                     11.0
# 44                     30.0
# 53                     22.0
# 96                      8.0
# 102                    30.0

# %%
df_orders[df_orders.eval_set == 'prior'].head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_order_products[df_order_products.order_id == 2774568]
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
cnt_eval_set_users = df_orders.groupby('eval_set')['user_id'].nunique()

cnt_eval_set_users = cnt_eval_set_users.reindex(['prior', 'train', 'test'])

sns.barplot(cnt_eval_set_users.index, cnt_eval_set_users.values)

plt.ylabel('Number of Users')
plt.xlabel('Eval Set Type')
plt.title('Count of Users in Each Dataset')
plt.show()

# %%
cnt_eval_set_users
# Out:
# eval_set
# prior    206209
# train    131209
# test      75000
# Name: user_id, dtype: int64

# %% [markdown]
# #### How many users in prior appear in train? How many users in prior or train appear in test?

# %%
df_orders_train = df_orders[df_orders['eval_set'] == 'train']
df_orders_prior = df_orders[df_orders['eval_set'] == 'prior']

# %%
len(pd.Series(list(set(df_orders_prior['user_id']) & set(df_orders_test['user_id']))))
# Out:
# 75000

# %%
len(pd.Series(list(set(df_orders_prior['user_id']) & set(df_orders_train['user_id']))))
# Out:
# 131209

# %%
len(pd.Series(list(set(df_orders_train['user_id']) & set(df_orders_test['user_id']))))
# Out:
# 0

# %% [markdown]
# All users in prior appear in either train or test. There is no overlap between users of train and test.

# %% [markdown]
# ### When are orders made?

# %%
plt.figure(figsize=(8,6))

sns.countplot(x="order_dow", data=df_orders, palette=sns.color_palette("BuGn_d",7))

plt.ylabel('Number of Orders')
plt.xlabel('Day of the Week')
plt.title('Number of Orders on Each Day of the Week')
plt.show()

# %% [markdown]
# It looks as though 0 represents Saturday and 1 represents Sunday. Wednesday is then the least popular day to make orders.

# %%
plt.figure(figsize=(10,6))

sns.countplot(x="order_hour_of_day", data=df_orders, palette=sns.color_palette("PuBu_d", 24))

plt.ylabel('Number of Orders')
plt.xlabel('Hour of the Day')
plt.xticks(rotation='vertical')
plt.title('Number of Orders on Each Hour of the Day')
plt.show()

# %% [markdown]
# The 10am hour is the most popular time to make orders, followed by a dip around lunch time and a pickup in the afternoon.

# %%
group_hour_dow = df_orders.groupby(['order_dow', 'order_hour_of_day'])['order_number'].aggregate('count').reset_index()
group_hour_dow = group_hour_dow.pivot('order_dow', 'order_hour_of_day', 'order_number')

plt.figure(figsize=(10,8))

sns.heatmap(group_hour_dow, cmap='YlOrRd')

plt.ylabel('Day of Week')
plt.xlabel('Hour of the Day')
plt.title('Number of Orders Day of Week vs Hour of Day')
plt.show()

# %% [markdown]
# Saturday afternoon and Sunday morning are the most popular time to make orders.

# %%
plt.figure(figsize=(12,6))

sns.countplot(x='days_since_prior_order', data=df_orders, palette='Reds_d')

plt.ylabel('Number of Orders')
plt.xlabel('Days Since Prior Order')
plt.xticks(rotation='vertical')
plt.title('Number of Orders by Days Since Prior Order')
plt.show()

# %% [markdown]
# While the most popular relative time between orders is monthly (30 days), there are "local maxima" at weekly (7 days), biweekly (14 days), triweekly (21 days), and quadriweekly (28 days).

# %% [markdown]
# ### Prior Orders

# %% [markdown]
# #### Count of Users by Number of Prior Orders

# %%
group_user_orders = df_orders.groupby('user_id')['order_number'].aggregate('max').reset_index()

# sns hist may be better; but possible to make bin size 1?

plt.figure(figsize=(14,6))

sns.barplot(x=group_user_orders['order_number'].value_counts().index, y=group_user_orders['order_number'].value_counts().values)

plt.title('Count of Users by Number of Prior Orders')
plt.xlabel('Number of Prior Orders')
plt.ylabel('Number of Users')
# Did not find a great way in seaborn to make tick labels for every other step; maybe try using xmin(), xmax() or just pandas:
plt.xticks(range(0, 99, 2), range(4,101,2), rotation='vertical')
plt.show()

# %%
group_user_orders['order_number'].value_counts().head()
# Out:
# 4    23986
# 5    19590
# 6    16165
# 7    13850
# 8    11700
# Name: order_number, dtype: int64

# %% [markdown]
# #### Distribution of Basket Sizes

# %%
order_sizes = d.reset_index().groupby(['user_id', 'order_number'])['add_to_cart_order'].aggregate('max')
order_sizes.head()

plt.figure(figsize=(14,8))

sns.barplot(order_sizes.value_counts().index, order_sizes.value_counts().values)

plt.title('Count of Orders by Number of Items in Basket')
plt.xlabel('Number of Items in Basket')
plt.ylabel('Number of Orders')
# Did not find a great way in seaborn to make tick labels for every other step; maybe try using xmin(), xmax() or just pandas:
plt.xticks(range(0, 145, 2), range(1,146,2), rotation='vertical')
plt.show()

# %% [markdown]
# As one might expect, the distribution is right-skew. The mode basket size is 5.

# %% [markdown]
# ### Popular Products, Departments, and Aisles

# %% [markdown]
# Now let's take a look at the most popular products

# %%
cnt_products = pd.crosstab(d.product_name, d.eval_set)
cnt_products['total'] = cnt_products.prior + cnt_products.train
cnt_products.sort_values(by='total', ascending=False).head(25)
# Out:
# eval_set                     prior  train   total
# product_name
# Banana                      472565  18726  491291
# Bag of Organic Bananas      379450  15480  394930
# Organic Strawberries        264683  10894  275577
# Organic Baby Spinach        241921   9784  251705
# Organic Hass Avocado        213584   7293  220877
# Organic Avocado             176815   7409  184224
# Large Lemon                 152657   8135  160792
# Strawberries                142951   6494  149445
# Limes                       140627   6033  146660
# Organic Whole Milk          137905   4908  142813
# Organic Raspberries         137057   5546  142603
# Organic Yellow Onion        113426   4290  117716
# Organic Garlic              109778   4158  113936
# Organic Zucchini            104823   4589  109412
# Organic Blueberries         100060   4966  105026
# Cucumber Kirby               97315   2413   99728
# Organic Fuji Apple           89632   3257   92889
# ...

# %%
cnt_products.sort_values(by='total', ascending=False).head(25)[['prior', 'train']].plot(kind='bar', stacked=True, figsize=(16,8))
plt.title('Count of Orders of the 25 Most Ordered Products')
plt.xlabel('Product')
plt.ylabel('Count of Orders')
plt.show()

# %% [markdown]
# Most of the 25 most popular products are fruits; most of the remainder are vegetables. A majority of the products are organic.

# %% [markdown]
# What about the most ordered from aisles?

# %%
cnt_aisles = pd.crosstab(d.aisle, d.eval_set)
cnt_aisles['total'] = cnt_aisles.prior + cnt_aisles.train
cnt_aisles.sort_values(by='total', ascending=False).head(15)
# Out:
# eval_set                         prior   train    total
# aisle
# fresh fruits                   3642188  150473  3792661
# fresh vegetables               3418021  150609  3568630
# packaged vegetables fruits     1765313   78493  1843806
# yogurt                         1452343   55240  1507583
# packaged cheese                 979763   41699  1021462
# milk                            891015   32644   923659
# water seltzer sparkling water   841533   36617   878150
# chips pretzels                  722470   31269   753739
# soy lactosefree                 638253   26240   664493
# bread                           584834   23635   608469
# refrigerated                    575881   23228   599109
# frozen produce                  522654   22453   545107
# ice cream ice                   498425   22676   521101
# crackers                        458838   19592   478430
# energy granola bars             456386   17449   473835

# %%
cnt_aisles.sort_values(by='total', ascending=False).head(15)[['prior', 'train']].plot(kind='bar', stacked=True, figsize=(16,8))
plt.title('Count of Orders in the 15 Most Ordered from Aisles')
plt.xlabel('Aisle')
plt.ylabel('Count of Orders')
plt.show()

# %% [markdown]
# Next, what about the distribution of departments ordered from?

# %%
cnt_departments = pd.crosstab(d.department, d.eval_set)
cnt_departments['total'] = cnt_departments.prior + cnt_departments.train
cnt_departments['total_pct'] = cnt_departments.total / cnt_departments.total.sum()
cnt_departments.sort_values(by='total', ascending=False)
# Out:
# eval_set           prior   train    total  total_pct
# department
# produce          9479291  409087  9888378   0.292390
# dairy eggs       5414016  217051  5631067   0.166505
# snacks           2887550  118862  3006412   0.088897
# beverages        2690129  114046  2804175   0.082917
# frozen           2236432  100426  2336858   0.069099
# pantry           1875577   81242  1956819   0.057861
# bakery           1176787   48394  1225181   0.036227
# canned goods     1068058   46799  1114857   0.032965
# deli             1051249   44291  1095540   0.032394
# dry goods pasta   866627   38713   905340   0.026770
# household         738666   35986   774652   0.022906
# meat seafood      708931   30307   739238   0.021859
# breakfast         709569   29500   739069   0.021854
# personal care     447123   21570   468693   0.013859
# babies            423802   14941   438743   0.012973
# international     269253   11902   281155   0.008313
# ...

# %%
cnt_departments.sort_values(by='total', ascending=False).total_pct.plot(kind='pie', autopct='%1.1f%%', figsize=(12,12))
plt.title('Proportion of Items Sold from Each Department')
plt.show()

# %%
# Treemaps are ugly in python. A nested pie chart with aisles as subgroups of departments (by both products in aisles and orders in aisles) could be nice.

# %% [markdown]
# ### Reorders

# %% [markdown]
# #### How many of the total items purchased are reorders?

# %%
print('{:.2%}'.format(d['reordered'].mean()))
# Out:
# 59.01%

# %% [markdown]
# Overall, $\hat p = 59.01\% = 0.5901$.

# %% [markdown]
# #### Which items are most likely to be reordered?
#
# Let's look at both the prior and train sets and limit to products which have been ordered at least 50 times.

# %%
# Find the product names with reorder rate, restricting to products ordered at least 50 times.
reorder_product = d.groupby('product_name').filter(lambda x: len(x) >= 50).groupby('product_name')['reordered'].mean().sort_values(ascending=False)

# Add aisle and departments names as well as give a count of the total number of orders of that product.
reorder_product_named = pd.merge(pd.DataFrame({'product_name':reorder_product.index, 'reordered_pct':reorder_product.values}), df_products, on='product_name')
reorder_product_named = pd.merge(reorder_product_named, df_aisles, on='aisle_id')
reorder_product_named = pd.merge(reorder_product_named, df_departments, on='department_id')
reorder_product_named = pd.merge(reorder_product_named, cnt_products, on='product_name')
del reorder_product_named['prior']
del reorder_product_named['train']
reorder_product_named.sort_values(by='reordered_pct', inplace=True, ascending=False)
reorder_product_named.reset_index(inplace=True, drop=True)

# %%
reorder_product_named[['product_name', 'reordered_pct']].head(10)
# Out:
#                                         product_name  reordered_pct
# 0                                Raw Veggie Wrappers       0.942029
# 1           Serenity Ultimate Extrema Overnight Pads       0.933333
# 2                                 Chocolate Love Bar       0.921569
# 3                                 Bars Peanut Butter       0.898551
# 4                          Soy Crisps Lightly Salted       0.895522
# 5                                    Maca Buttercups       0.894231
# 6                              Benchbreak Chardonnay       0.891892
# 7                           Organic Blueberry B Mega       0.888889
# 8                                     Sparking Water       0.887097
# 9  Fragrance Free Clay with Natural Odor Eliminat...       0.870229

# %%
# Display first and last 5 with '...' separator. Find better way.

reorder_product_named.sort_values('reordered_pct', ascending=False)[:5]\
.append(pd.Series('...', index=reorder_product_named.columns), ignore_index=True)\
.append(reorder_product_named.sort_values('reordered_pct', ascending=False)[-5:], ignore_index=True)
# Out:
#                                 product_name reordered_pct product_id  \
# 0                        Raw Veggie Wrappers      0.942029       6433
# 1   Serenity Ultimate Extrema Overnight Pads      0.933333       2075
# 2                         Chocolate Love Bar      0.921569      27740
# 3                         Bars Peanut Butter      0.898551      36543
# 4                  Soy Crisps Lightly Salted      0.895522      26093
# 5                                        ...           ...        ...
# 6                           Whole Cumin Seed             0      28116
# 7                            Gel Food Colors             0      18267
# 8                Nonpareil Decorating Decors             0      42461
# 9                     Organic Whole Rosemary             0      37673
# 10                        Round Cake Pan 9\"             0      24322
#
#    aisle_id department_id                  aisle     department total
# ...

# %% [markdown]
# ##### Hypothesis Testing
#
# There are significant differences between reorder proportions. Since we have assumed that the number of product orders is at least 50, the differences in reorder proportions between different products is statistically significant whenever the difference in reorder proportions is at least $0.20$ and the reorder proportions are between $0.2$ and $0.8$.
#
# Define the pooled proportion, $\hat{p}$, the standard error, $SE$, and $z$-statistic by
#
# \begin{equation*}
# \hat{p} = \frac{x_1 + x_2}{n_1 + n_2}
# \end{equation*}
#
# \begin{equation*}
# SE = \sqrt{\hat{p} (1-\hat{p}) \left(n_1^{-1} + n_2^{-1}\right)}
# \end{equation*}
#
# \begin{equation*}
# z = \frac{\hat{p}_1 - \hat{p}_2}{SE}
# \end{equation*}
#
# where $\hat{p}_1$, $\hat{p}_2$ are reorder proportions; $n_1$, $n_2$ are total orders; and $x_1$, $x_2$ are reorders for two products. At a level of significance $\alpha = 0.05$, we need $|z| > 2$, i.e.
# \begin{equation*}
# 2 < |z| = \left| \frac{\hat{p}_1 - \hat{p}_2}{SE} \right|
# \end{equation*}
#
# which, using the above formula for standard error, is
# \begin{equation*}
# 2 \sqrt{\hat{p} (1-\hat{p}) \left(n_1^{-1} + n_2^{-1}\right)} < \left| \hat{p}_1 - \hat{p}_2 \right|.
# \end{equation*}
#
# We can minimize the left hand side to obtain the best lower bound for the difference in proportions $\left| \hat{p}_1 - \hat{p}_2 \right|$ by choosing $\hat{p} = 0.5$ and minimizing $n_1$ and $n_2$. Smaller sample sizes and smaller differences between sample statistics yield a smaller (in magnitude) $z$-statistic; for such samples we are less likely to adopt $H_1$ (stated below) than for larger samples or samples with larger differences in reorder proportions. When $n_1 = n_2 = 50$ and $\hat{p} = 0.5$,
# \begin{equation*}
# 0.2 < \left| \hat{p}_1 - \hat{p}_2 \right|.
# \end{equation*}
#
# In order to construct hypothesis tests, compare the reorder proportions of a few pairs of products as a "spot check". We have assumed that the number of product orders is at least 50, so as long as $0.2 < \hat p < 0.8$, the conditions for the CLT (two sample; proportions) are satisfied. They may be satisfied for products with more extreme reorder proportions that have a greater number of product orders.
#
# Choose the 5,000th, 10,000th, 15,000th, and 20,000th most reordered product (with at least 50 orders) to compare. In the code below we compute:
#
# \begin{equation*}
# \begin{array}{|l|c|c|c|c|}
# \hline
# & 5000 & \ 10000 & 15000 & 20000 \\ \hline
# \text{mean} & \hat{p}_{5000} = 0.614286 & \hat{p}_{10000} = 0.530499 & \hat{p}_{15000} = 0.451327 & \hat{p}_{20000} = 0.353116 \\ \hline
# \text{number} & n_{5000} = 70 & n_{10000} = 541 & n_{15000} = 113 & n_{20000} = 1011 \\ \hline
# \text{reorders} & x_{5000} = 43 & x_{10000} = 287 & x_{15000} = 51 & x_{20000} = 357 \\ \hline
# \end{array}
# \end{equation*}
#
#
# For $n \in \{5000, 10000, 15000, 20000\}$, let $p_n$ be the population reorder proportion. Form and test the hypotheses
#
# $H_0: p_{n} = p_{m}$
#
# $H_1: p_{n} \neq p_{m}$
#
# where $n, m \in \{5000, 10000, 15000, 20000\}$, using frequentist tests at a level of significance $\alpha = 0.05$. Let's reveal what these four products are:

# %%
alpha = 0.05

# %%
mu_5000 = reorder_product_named['reordered_pct'].loc[5000]
num_5000 = reorder_product_named['total'].loc[5000]
re_5000 = round(mu_5000 * num_5000)
reorder_product_named.loc[5000]
# Out:
# product_name     Classic Strawberry Serenity Kombucha
# reordered_pct                                0.614286
# product_id                                      42593
# aisle_id                                           31
# department_id                                       7
# aisle                                    refrigerated
# department                                  beverages
# total                                              70
# Name: 5000, dtype: object

# %%
mu_10000 = reorder_product_named['reordered_pct'].loc[10000]
num_10000 = reorder_product_named['total'].loc[10000]
re_10000 = round(mu_10000 * num_10000)
reorder_product_named.loc[10000]
# Out:
# product_name     Mushroom Ravioli
# reordered_pct            0.530499
# product_id                   4034
# aisle_id                       12
# department_id                   9
# aisle                 fresh pasta
# department        dry goods pasta
# total                         541
# Name: 10000, dtype: object

# %%
mu_15000 = reorder_product_named['reordered_pct'].loc[15000]
num_15000 = reorder_product_named['total'].loc[15000]
re_15000 = round(mu_15000 * num_15000)
reorder_product_named.loc[15000]
# Out:
# product_name     Cranberry Concord Grape Juice
# reordered_pct                         0.451327
# product_id                               42114
# aisle_id                                    98
# department_id                                7
# aisle                            juice nectars
# department                           beverages
# total                                      113
# Name: 15000, dtype: object

# %%
mu_20000 = reorder_product_named['reordered_pct'].loc[20000]
num_20000 = reorder_product_named['total'].loc[20000]
re_20000 = round(mu_20000 * num_20000)
reorder_product_named.loc[20000]
# Out:
# product_name     Cheese Shredded Mozzarella Low Moisture Part Skim
# reordered_pct                                             0.353116
# product_id                                                   42423
# aisle_id                                                        21
# department_id                                                   16
# aisle                                              packaged cheese
# department                                              dairy eggs
# total                                                         1011
# Name: 20000, dtype: object

# %% [markdown]
# The differences in reorder proportions for different products is often statistically and practically significant, justifying its use in making predictions:

# %% [markdown]
# * $(n, m) = (5000, 10000)$:

# %%
print(reorder_product_named['product_name'].loc[5000] + ' was ordered %i times.\n\
Of those, %i were reorders. The proportion of reorders is %.4f.' % (num_5000, re_5000, mu_5000))

print(reorder_product_named['product_name'].loc[10000] + ' was ordered %i times.\n\
Of those, %i were reorders. The proportion of reorders is %.4f.' % (num_10000, re_10000, mu_10000))

print('The difference in proportions is %.4f.' % (mu_5000 - mu_10000))

pool = (re_5000 + re_10000) / (num_5000 + num_10000) # pooled proportion

z_stat = (mu_5000 - mu_10000) / math.sqrt(pool * (1-pool) * (1/num_5000 + 1/num_10000))
p_value = 2 * stats.norm.sf(abs(z_stat)) # Two-tail
print('The z-statistic is %.2f. and the p-value is %.5f.' % (z_stat, p_value))

if p_value > alpha:
    print('Fail to reject H_0.')
else:
    print('Reject H_0.')
# Out:
# Classic Strawberry Serenity Kombucha was ordered 70 times.
# Of those, 43 were reorders. The proportion of reorders is 0.6143.
# Mushroom Ravioli was ordered 541 times.
# Of those, 287 were reorders. The proportion of reorders is 0.5305.
# The difference in proportions is 0.0838.
# The z-statistic is 1.32. and the p-value is 0.18566.
# Fail to reject H_0.

# %% [markdown]
# * $(n, m) = (5000, 15000)$:

# %%
print(reorder_product_named['product_name'].loc[5000] + ' was ordered %i times.\n\
Of those, %i were reorders. The proportion of reorders is %.4f.' % (num_5000, re_5000, mu_5000))

print(reorder_product_named['product_name'].loc[15000] + ' was ordered %i times.\n\
Of those, %i were reorders. The proportion of reorders is %.4f.' % (num_15000, re_15000, mu_15000))

print('The difference in proportions is %.4f.' % (mu_5000 - mu_15000))

pool = (re_5000 + re_15000) / (num_5000 + num_15000) # pooled proportion

z_stat = (mu_5000 - mu_15000) / math.sqrt(pool * (1-pool) * (1/num_5000 + 1/num_15000))
p_value = 2 * stats.norm.sf(abs(z_stat)) # Two-tail
print('The z-statistic is %.2f. and the p-value is %.5f.' % (z_stat, p_value))

if p_value > alpha:
    print('Fail to reject H_0.')
else:
    print('Reject H_0.')
# Out:
# Classic Strawberry Serenity Kombucha was ordered 70 times.
# Of those, 43 were reorders. The proportion of reorders is 0.6143.
# Cranberry Concord Grape Juice was ordered 113 times.
# Of those, 51 were reorders. The proportion of reorders is 0.4513.
# The difference in proportions is 0.1630.
# The z-statistic is 2.14. and the p-value is 0.03207.
# Reject H_0.

# %% [markdown]
# * $(n, m) = (5000, 20000)$:

# %%
print(reorder_product_named['product_name'].loc[5000] + ' was ordered %i times.\n\
Of those, %i were reorders. The proportion of reorders is %.4f.' % (num_5000, re_5000, mu_5000))

print(reorder_product_named['product_name'].loc[20000] + ' was ordered %i times.\n\
Of those, %i were reorders. The proportion of reorders is %.4f.' % (num_20000, re_20000, mu_20000))

print('The difference in proportions is %.4f.' % (mu_5000 - mu_20000))

pool = (re_5000 + re_20000) / (num_5000 + num_20000) # pooled proportion

z_stat = (mu_5000 - mu_20000) / math.sqrt(pool * (1-pool) * (1/num_5000 + 1/num_20000))
p_value = 2 * stats.norm.sf(abs(z_stat)) # Two-tail
print('The z-statistic is %.2f. and the p-value is %.5f.' % (z_stat, p_value))

if p_value > alpha:
    print('Fail to reject H_0.')
else:
    print('Reject H_0.')
# Out:
# Classic Strawberry Serenity Kombucha was ordered 70 times.
# Of those, 43 were reorders. The proportion of reorders is 0.6143.
# Cheese Shredded Mozzarella Low Moisture Part Skim was ordered 1011 times.
# Of those, 357 were reorders. The proportion of reorders is 0.3531.
# The difference in proportions is 0.2612.
# The z-statistic is 4.38. and the p-value is 0.00001.
# Reject H_0.

# %% [markdown]
# * $(n, m) = (10000, 15000)$:

# %%
print(reorder_product_named['product_name'].loc[10000] + ' was ordered %i times.\n\
Of those, %i were reorders. The proportion of reorders is %.4f.' % (num_10000, re_10000, mu_10000))

print(reorder_product_named['product_name'].loc[15000] + ' was ordered %i times.\n\
Of those, %i were reorders. The proportion of reorders is %.4f.' % (num_15000, re_15000, mu_15000))

print('The difference in proportions is %.4f.' % (mu_10000 - mu_15000))

pool = (re_10000 + re_15000) / (num_10000 + num_15000) # pooled proportion

z_stat = (mu_10000 - mu_15000) / math.sqrt(pool * (1-pool) * (1/num_10000 + 1/num_15000))
p_value = 2 * stats.norm.sf(abs(z_stat)) # Two-tail
print('The z-statistic is %.2f. and the p-value is %.5f.' % (z_stat, p_value))

if p_value > alpha:
    print('Fail to reject H_0.')
else:
    print('Reject H_0.')
# Out:
# Mushroom Ravioli was ordered 541 times.
# Of those, 287 were reorders. The proportion of reorders is 0.5305.
# Cranberry Concord Grape Juice was ordered 113 times.
# Of those, 51 were reorders. The proportion of reorders is 0.4513.
# The difference in proportions is 0.0792.
# The z-statistic is 1.53. and the p-value is 0.12558.
# Fail to reject H_0.

# %% [markdown]
# * $(n, m) = (10000, 20000)$:

# %%
print(reorder_product_named['product_name'].loc[10000] + ' was ordered %i times.\n\
Of those, %i were reorders. The proportion of reorders is %.4f.' % (num_10000, re_10000, mu_10000))

print(reorder_product_named['product_name'].loc[20000] + ' was ordered %i times.\n\
Of those, %i were reorders. The proportion of reorders is %.4f.' % (num_20000, re_20000, mu_20000))

print('The difference in proportions is %.4f.' % (mu_10000 - mu_20000))

pool = (re_10000 + re_20000) / (num_10000 + num_20000) # pooled proportion

z_stat = (mu_10000 - mu_20000) / math.sqrt(pool * (1-pool) * (1/num_10000 + 1/num_20000))
p_value = 2 * stats.norm.sf(abs(z_stat)) # Two-tail
print('The z-statistic is %.2f. and the p-value is %.5f.' % (z_stat, p_value))

if p_value > alpha:
    print('Fail to reject H_0.')
else:
    print('Reject H_0.')
# Out:
# Mushroom Ravioli was ordered 541 times.
# Of those, 287 were reorders. The proportion of reorders is 0.5305.
# Cheese Shredded Mozzarella Low Moisture Part Skim was ordered 1011 times.
# Of those, 357 were reorders. The proportion of reorders is 0.3531.
# The difference in proportions is 0.1774.
# The z-statistic is 6.76. and the p-value is 0.00000.
# Reject H_0.

# %% [markdown]
# * $(n, m) = (15000, 20000)$:

# %%
print(reorder_product_named['product_name'].loc[15000] + ' was ordered %i times.\n\
Of those, %i were reorders. The proportion of reorders is %.4f.' % (num_15000, re_15000, mu_15000))

print(reorder_product_named['product_name'].loc[20000] + ' was ordered %i times.\n\
Of those, %i were reorders. The proportion of reorders is %.4f.' % (num_20000, re_20000, mu_20000))

print('The difference in proportions is %.4f.' % (mu_15000 - mu_20000))

pool = (re_15000 + re_20000) / (num_15000 + num_20000) # pooled proportion

z_stat = (mu_15000 - mu_20000) / math.sqrt(pool * (1-pool) * (1/num_15000 + 1/num_20000))
p_value = 2 * stats.norm.sf(abs(z_stat)) # Two-tail
print('The z-statistic is %.2f. and the p-value is %.5f.' % (z_stat, p_value))

if p_value > alpha:
    print('Fail to reject H_0.')
else:
    print('Reject H_0.')
# Out:
# Cranberry Concord Grape Juice was ordered 113 times.
# Of those, 51 were reorders. The proportion of reorders is 0.4513.
# Cheese Shredded Mozzarella Low Moisture Part Skim was ordered 1011 times.
# Of those, 357 were reorders. The proportion of reorders is 0.3531.
# The difference in proportions is 0.0982.
# The z-statistic is 2.06. and the p-value is 0.03949.
# Reject H_0.

# %% [markdown]
# #### What is the reorder ratio by department?

# %%
d.groupby('department')['reordered'].mean().plot(kind='bar', figsize=(16,8))

# %% [markdown]
# It looks as though dairy eggs have the highest reorder rate while personal care has the lowest.

# %% [markdown]
# #### What about the reorder ratio by aisle?

# %%
# Display first and last 5 with '...' separator. Find better way.

reorder_aisle = d.groupby(['aisle', 'department'])['reordered'].mean().to_frame().reset_index()

reorder_aisle.sort_values('aisle')[:5]\
.append(pd.Series('...', index=reorder_aisle.columns), ignore_index=True)\
.append(reorder_aisle.sort_values('aisle')[-5:], ignore_index=True)
# Out:
#                             aisle     department reordered
# 0          air fresheners candles      household  0.310737
# 1                     asian foods  international  0.351274
# 2                baby accessories         babies    0.5515
# 3             baby bath body care         babies  0.294758
# 4               baby food formula         babies  0.589005
# 5                             ...            ...       ...
# 6               trash bags liners      household  0.336983
# 7            vitamins supplements  personal care  0.312176
# 8   water seltzer sparkling water      beverages   0.72993
# 9                     white wines        alcohol  0.631928
# 10                         yogurt     dairy eggs  0.686501

# %%
# Display first and last 5 with '...' separator. Find better way.

reorder_aisle.sort_values('reordered', ascending=False)[:5]\
.append(pd.Series('...', index=reorder_aisle.columns), ignore_index=True)\
.append(reorder_aisle.sort_values('reordered', ascending=False)[-5:], ignore_index=True)
# Out:
#                             aisle     department reordered
# 0                            milk     dairy eggs  0.781812
# 1   water seltzer sparkling water      beverages   0.72993
# 2                    fresh fruits        produce  0.718823
# 3                            eggs     dairy eggs  0.706359
# 4                 soy lactosefree     dairy eggs  0.692361
# 5                             ...            ...       ...
# 6                          beauty  personal care  0.212858
# 7                       first aid  personal care  0.195864
# 8                kitchen supplies      household  0.194802
# 9           baking supplies decor         pantry  0.167595
# 10              spices seasonings         pantry  0.152933

# %%
plt.figure(figsize=(18,32))

ax = sns.stripplot(x='department', y='reordered', data=reorder_aisle, jitter=False)

plt.xticks(rotation='vertical')

# Make a list of all department names with the same ordinal values as seaborn plot
dep_cat = reorder_aisle['department'].unique().tolist()

# Annotate with aisle names
for i in range(reorder_aisle.shape[0]):
    # Add some distance for overlapping annotations in the same category. More work necessary for multiple overlapping annotations.
    if (reorder_aisle[reorder_aisle['department'] == reorder_aisle['department'].iloc[i]]['reordered'] \
        - reorder_aisle['reordered'].iloc[i]).between(-0.0025, 0, inclusive=False).any(): 
        ax.annotate(reorder_aisle['aisle'].iloc[i],
                    xy=(dep_cat.index(reorder_aisle['department'].iloc[i]), reorder_aisle['reordered'].iloc[i]),
                    xytext=(dep_cat.index(reorder_aisle['department'].iloc[i])+0.1, reorder_aisle['reordered'].iloc[i]+0.0025))
    else:
        ax.annotate(reorder_aisle['aisle'].iloc[i],
                    xy=(dep_cat.index(reorder_aisle['department'].iloc[i]), reorder_aisle['reordered'].iloc[i]),
                    xytext=(dep_cat.index(reorder_aisle['department'].iloc[i])+0.1, reorder_aisle['reordered'].iloc[i]))

plt.show()

# %% [markdown]
# ##### Hypothesis Testing
#
# Due to the large number of orders in our dataset, the differences in reorder proportions between different aisles is statistically significant, as long as the difference in reorder proportions is at least $0.02$, two percentage points. This follows from the identity we derived above,
# \begin{equation*}
# 2 \sqrt{\hat{p} (1-\hat{p}) \left(n_1^{-1} + n_2^{-1}\right)} < \left| \hat{p}_1 - \hat{p}_2 \right|,
# \end{equation*}
# with $n_1 = n_2 = 5000$ (and $\hat{p} = 0.5$), which is a lower bound on the number of orders per aisle.
#
#
# In order to construct a hypothesis test, compare the reorder proportions of two of the least frequented† aisles which, in addition, have a relatively small difference in reorder proportions. The `beauty` and `deodorants` aisles, for example, satisfy these conditions. These are also two samples which satisfy the conditions of the CLT for proportions. Smaller sample sizes and smaller differences between sample statistics yield a smaller (in magnitude) $z$-statistic; for such samples we are less likely to adopt $H_1$ (stated below) than for larger samples or samples with larger differences in reorder proportions. In the code below we compute:
#
# \begin{equation*}
# \begin{array}{|l|c|c|}
# \hline
# & \text{beauty} & \text{deodorants} \\ \hline
# \text{mean} & \hat{p}_{\text{beauty}} = 0.2129 & \hat{p}_{\text{deodorants}} = 0.2388 \\ \hline
# \text{number} & n_{\text{beauty}} = 6455 & n_{\text{deodorants}} = 15673 \\ \hline
# \text{reorders} & x_{\text{beauty}} = 1374 & x_{\text{deodorants}} = 3743 \\ \hline
# \end{array}
# \end{equation*}
#
#
# For the `beauty` population reorder proportion $p_{\text{beauty}}$ and the `deodorants` population reorder proportion $p_{\text{deodorants}}$, form and test the hypotheses
#
# $H_0: p_{\text{beauty}} = p_{\text{deodorants}}$
#
# $H_1: p_{\text{beauty}} \neq p_{\text{deodorants}}$
#
# using frequentist tests at a level of significance $\alpha = 0.05$.
#
# †least-frequented? [[1]](https://en.wikipedia.org/wiki/English_compound#Hyphenated_compound_modifiers) [[2]](https://english.stackexchange.com/questions/21104/hyphen-or-no-hyphen-when-modifying-an-adjective-with-a-quantity) [[3]](https://www.grammarly.com/blog/hyphen/)

# %%
alpha = 0.05

# %%
d.groupby('aisle')['aisle_id'].count().sort_values().head(15)
# Out:
# aisle
# frozen juice                   5147
# beauty                         6455
# baby accessories               8466
# baby bath body care            8909
# eye ear care                   9522
# kitchen supplies               9620
# skin care                     10698
# shave needs                   10876
# first aid                     11411
# specialty wines champagnes    11659
# ice cream toppings            11706
# kosher foods                  12426
# facial care                   12915
# deodorants                    15673
# indian foods                  16620
# Name: aisle_id, dtype: int64

# %% [markdown]
# Note that `beauty` is the second-least frequented aisle and `deodorants` are the 14th-least frequented aisle, out of 134 aisles.

# %%
mu_beauty = d[d['aisle'] == 'beauty']['reordered'].mean()
num_beauty = len(d[d['aisle'] == 'beauty'])
re_beauty = len(d[(d['aisle'] == 'beauty') & (d['reordered'] == 1)])

print('The number of items ordered from the beauty aisle is %i.\n\
Of those, %i are reorders. The proportion of reorders is %.4f.' % (num_beauty, re_beauty, mu_beauty))

mu_deodorants = d[d['aisle'] == 'deodorants']['reordered'].mean()
num_deodorants = len(d[d['aisle'] == 'deodorants'])
re_deodorants = len(d[(d['aisle'] == 'deodorants') & (d['reordered'] == 1)])

print('The number of items ordered from the deodorants aisle is %i.\n\
Of those, %i are reorders. The proportion of reorders is %.4f.' % (num_deodorants, re_deodorants, mu_deodorants))

print('The difference in proportions is %.4f.' % (mu_beauty - mu_deodorants))

pool = (re_deodorants + re_beauty) / (num_deodorants + num_beauty) # pooled proportion

z_stat = (mu_deodorants - mu_beauty) / math.sqrt(pool * (1-pool) * (1/num_deodorants + 1/num_beauty))
p_value = 2 * stats.norm.sf(abs(z_stat)) # Two-tail
print('The z-statistic is %.2f. and the p-value is %.5f.' % (z_stat, p_value))

if p_value > alpha:
    print('Fail to reject H_0.')
else:
    print('Reject H_0.')
# Out:
# The number of items ordered from the beauty aisle is 6455.
# Of those, 1374 are reorders. The proportion of reorders is 0.2129.
# The number of items ordered from the deodorants aisle is 15673.
# Of those, 3743 are reorders. The proportion of reorders is 0.2388.
# The difference in proportions is -0.0260.
# The z-statistic is 4.16. and the p-value is 0.00003.
# Reject H_0.

# %% [markdown]
# Even for two reorder proportions which are close in value $\left(\hat{p}_{\text{beauty}} - \hat{p}_{\text{deodorants}} = -0.026\right)$ and have small subsample sizes, the difference in proportions is significant. Given the reasoning above, this suggests that the difference in reorder proportions between most aisles is statistically significant. Therefore, we can justify using `aisle` to make predictions.

# %% [markdown]
# For reorder proportions which are very close in value, even for aisles that do not have a small number of orders, we can fail to reject $H_0$. To demonstrate, consider the `yogurt` and `cream` aisles.
#
# $$
# \begin{array}{|l|c|c|}
# \hline
# & \text{yogurt} & \text{cream} \\ \hline
# \text{mean} & \hat{p}_{\text{yogurt}} = 0.6865 & \hat{p}_{\text{cream}} = 0.6852 \\ \hline
# \text{number} & n_{\text{yogurt}} = 1507583 & n_{\text{cream}} = 330358 \\ \hline
# \text{reorders} & x_{\text{yogurt}} = 1034957 & x_{\text{cream}} = 226356 \\ \hline
# \end{array}
# $$
#
# Note that the difference in reorder proportions is $\hat{p}_{\text{yogurt}} - \hat{p}_{\text{cream}} = 0.0013.$
#
# For the `yogurt` population reorder proportion $p_{\text{yogurt}}$ and the `cream` population reorder proportion $p_{\text{cream}}$, form and test the hypotheses
#
# $H_0: p_{\text{yogurt}} = p_{\text{cream}}$
#
# $H_1: p_{\text{yogurt}} \neq p_{\text{cream}}$
#
# using frequentist tests at a level of significance $\alpha = 0.05$.

# %%
mu_yogurt = d[d['aisle'] == 'yogurt']['reordered'].mean()
num_yogurt = len(d[d['aisle'] == 'yogurt'])
re_yogurt = len(d[(d['aisle'] == 'yogurt') & (d['reordered'] == 1)]) # == mu * num

print('The number of items ordered from the yogurt aisle is %i.\n\
Of those, %i are reorders. The proportion of reorders is %.4f.' % (num_yogurt, re_yogurt, mu_yogurt))

mu_cream = d[d['aisle'] == 'cream']['reordered'].mean()
num_cream = len(d[d['aisle'] == 'cream'])
re_cream = len(d[(d['aisle'] == 'cream') & (d['reordered'] == 1)]) # == mu * num

print('The number of items ordered from the cream aisle is %i.\n\
Of those, %i are reorders. The proportion of reorders is %.4f.' % (num_cream, re_cream, mu_cream))

print('The difference in proportions is %.4f.' % (mu_yogurt - mu_cream))

pool = (re_cream + re_yogurt) / (num_cream + num_yogurt) # pooled proportion

z_stat = (mu_cream - mu_yogurt) / math.sqrt(pool * (1-pool) * (1/num_cream + 1/num_yogurt))
p_value = 2 * stats.norm.sf(abs(z_stat)) # Two-tail
print('The z-statistic is %.2f. and the p-value is %.5f.' % (z_stat, p_value))

if p_value > alpha:
    print('Fail to reject H_0.')
else:
    print('Reject H_0.')
# Out:
# The number of items ordered from the yogurt aisle is 1507583.
# Of those, 1034957 are reorders. The proportion of reorders is 0.6865.
# The number of items ordered from the cream aisle is 330358.
# Of those, 226356 are reorders. The proportion of reorders is 0.6852.
# The difference in proportions is 0.0013.
# The z-statistic is -1.48. and the p-value is 0.13958.
# Fail to reject H_0.

# %% [markdown]
# We cannot conclude that such a small difference in reorder proportions is statistically significant.

# %% [markdown]
# We can estimate from the above that, roughly speaking, as long as the difference in reorder proportions is $\gtrsim 0.01$, that difference is statistically significant. A $p$-value of $0.05$ corresponds to a difference in proportions of roughly $0.014$, assuming a proportion of $0.5$ and sample sizes of $10,000$.

# %%
stats.norm.ppf(0.975) * math.sqrt(0.5 * 0.5 * (1/10000 + 1/10000)) # == diff of props
# Out:
# 0.013859038243496779

# %% [markdown]
# #### What about the reorder ratio by the hour of the day or the day of the week?

# %%
plt.figure(figsize=(8,6))

sns.catplot(x='order_dow', y='reordered', kind='bar',\
            data=d.groupby(['order_dow'])['reordered'].aggregate('mean').reset_index(),\
            palette=sns.color_palette("BuGn_d",7)
           )

plt.ylabel('Reorder Proportion')
plt.xlabel('Day of the Week')
plt.title('Reorder Proportion on Each Day of the Week')
plt.show()

# %% [markdown]
# This distribution is nearly uniform. While there is a visible difference between reorder proportion on Sunday and reorder proportion on Friday, it may not be significant.

# %%
plt.figure(figsize=(10,6))

sns.catplot(x="order_hour_of_day", y='reordered', kind='bar',\
            data=d.groupby(['order_hour_of_day'])['reordered'].aggregate('mean').reset_index(),\
            palette=sns.color_palette("PuBu_d", 24)
           )

plt.ylabel('Reorder Proportion')
plt.xlabel('Hour of the Day')
plt.xticks(rotation='vertical')
plt.title('Reorder Proportion on Each Hour of the Day')
plt.show()

# %% [markdown]
# We will check the significance of what appears to be a peak in reorders at 7am, preceded by a smaller dip at 2am.

# %%
reorder_hour_dow = d.groupby(['order_dow', 'order_hour_of_day'])['reordered'].aggregate('mean').reset_index()
reorder_hour_dow = reorder_hour_dow.pivot('order_dow', 'order_hour_of_day', 'reordered')

plt.figure(figsize=(10,8))

sns.heatmap(reorder_hour_dow, cmap='YlOrRd')

plt.ylabel('Day of Week')
plt.xlabel('Hour of the Day')
plt.title('Reorder Proportion by Day of Week vs Hour of Day')
plt.show()

# %% [markdown]
# It looks as though mornings, especially Sunday mornings, are prime time for reorders. On the other hand, late-night mid-week reorders are the least likely.

# %% [markdown]
# ##### Hypothesis Testing
#
# Let's inspect the significance of differences in reorder ratio by time of day and day of week. If we presume the same conditions as in our above tests, then differences in reorder proportions between aisles are significant when the difference is at least $0.02$. This is because there are no `(order_dow, order_hour_of_day)` pairs for which the number of orders is less than 5000. We will use the same strategy that we used to examine the significance of differences in reorder ratio by aisle. Pick two pairs of `(order_dow, order_hour_of_day)` with a small difference in reorder proportion and a relatively small number of orders to potentially demonstrate significance for larger differences in reorder proportion and sample size.

# %%
# Numerical values which are displayed in the above heatmap
reorder_hour_dow
# Out:
# order_hour_of_day        0         1         2         3         4         5   \
# order_dow
# 0                  0.576550  0.553474  0.554843  0.568533  0.548804  0.593939
# 1                  0.590223  0.591805  0.556773  0.575907  0.597298  0.625008
# 2                  0.565236  0.560328  0.565167  0.578346  0.566349  0.611795
# 3                  0.554133  0.535516  0.543409  0.549647  0.549194  0.605566
# 4                  0.556915  0.540088  0.545530  0.561249  0.584238  0.607564
# 5                  0.548980  0.550912  0.560946  0.546990  0.592179  0.616801
# 6                  0.556838  0.565372  0.560270  0.543677  0.566370  0.591974
#
# order_hour_of_day        6         7         8         9   ...        14  \
# order_dow                                                  ...
# 0                  0.623720  0.641375  0.628425  0.608782  ...  0.576480
# 1                  0.659281  0.671103  0.661747  0.650900  ...  0.590289
# ...

# %%
reorder_hour_dow.idxmin(axis=1)
# Out:
# order_dow
# 0    4
# 1    2
# 2    1
# 3    1
# 4    1
# 5    3
# 6    3
# dtype: int64

# %%
# Count of number of orders by (order_dow, order_hour_of_day)
reorder_hour_dow_count = d.groupby(['order_dow', 'order_hour_of_day'])['order_id'].aggregate('count').reset_index()
reorder_hour_dow_count = reorder_hour_dow_count.pivot('order_dow', 'order_hour_of_day', 'order_id')
reorder_hour_dow_count
# Out:
# order_hour_of_day     0      1      2     3     4      5      6       7   \
# order_dow
# 0                  40444  23647  13566  9375  8739  12242  36425  140403
# 1                  38560  18866  11132  7305  7919  14979  54881  170880
# 2                  30957  15250   8693  7352  7144  13243  45158  127152
# 3                  28513  14205   9111  6093  7196  12253  42426  115125
# 4                  25740  14281   8434  6596  7182  12560  41609  118105
# 5                  30890  16057   9894  8704  9232  15368  48189  134439
# 6                  32927  19106  11830  8334  8302  11264  33954  122135
#
# order_hour_of_day      8       9   ...      14      15      16      17  \
# order_dow                          ...
# 0                  321927  462336  ...  595896  581287  527908  416816
# 1                  343737  521484  ...  471210  459764  435568  352051
# 2                  231210  339918  ...  348250  347439  343865  289659
# ...

# %%
# Count of number of reorders by (order_dow, order_hour_of_day)
reorder_hour_dow_success = d.groupby(['order_dow', 'order_hour_of_day'])['reordered'].aggregate('sum').reset_index()
reorder_hour_dow_success = reorder_hour_dow_success.pivot('order_dow', 'order_hour_of_day', 'reordered')
reorder_hour_dow_success
# Out:
# order_hour_of_day     0      1     2     3     4     5      6       7   \
# order_dow
# 0                  23318  13088  7527  5330  4796  7271  22719   90051
# 1                  22759  11165  6198  4207  4730  9362  36182  114678
# 2                  17498   8545  4913  4252  4046  8102  28896   81695
# 3                  15800   7607  4951  3349  3952  7420  26842   73910
# 4                  14335   7713  4601  3702  4196  7631  26654   75208
# 5                  16958   8846  5550  4761  5467  9479  30382   85071
# 6                  18335  10802  6628  4531  4702  6668  21123   77794
#
# order_hour_of_day      8       9   ...      14      15      16      17  \
# order_dow                          ...
# 0                  202307  281462  ...  343522  336483  304386  238533
# 1                  227467  339434  ...  278150  267876  252249  203956
# 2                  146262  211211  ...  202992  201412  200205  166025
# ...

# %% [markdown]
# * Tuesday midnight and Tuesday 1am, i.e. $(3,0)$ and $(3,1)$:
#
# $$
# \begin{array}{|l|c|c|}
# \hline
# & \text{(3,0)} & \text{(3,1)} \\ \hline
# \text{mean} & \hat{p}_{\text{(3,0)}} = 0.554133 & \hat{p}_{\text{(3,1)}} = 0.535516 \\ \hline
# \text{number} & n_{\text{(3,0)}} = 28513 & n_{\text{(3,1)}} = 14205 \\ \hline
# \text{reorders} & x_{\text{(3,0)}} = 15800 & x_{\text{(3,1)}} = 7607 \\ \hline
# \end{array}
# $$

# %%
mu_31, mu_30 = reorder_hour_dow.loc[3,1], reorder_hour_dow.loc[3,0]
num_31, num_30 = reorder_hour_dow_count.loc[3,1], reorder_hour_dow_count.loc[3,0]
re_31, re_30 = reorder_hour_dow_success.loc[3,1], reorder_hour_dow_success.loc[3,0]

print('The number of items ordered during (3,1) is %i.\n\
Of those, %i are reorders. The proportion of reorders is %.4f.' % (num_31, re_31, mu_31))

print('The number of items ordered during (3,0) is %i.\n\
Of those, %i are reorders. The proportion of reorders is %.4f.' % (num_30, re_30, mu_30))

print('The difference in proportions is %.4f.' % (mu_30 - mu_31))

pool = ((mu_31 * num_31) + (mu_30 * num_30)) / (num_31 + num_30)

stderr = math.sqrt(pool * (1-pool) * (1/num_31 + 1/num_30))

print('The margin of error is %.5f' % (2 * stderr))

z_stat = (mu_30 - mu_31) / stderr

p_value = 2 * stats.norm.sf(abs(z_stat)) # Two-tail
print('The z-statistic is %.2f. and the p-value is %.5f.' % (z_stat, p_value))

if p_value > alpha:
    print('Fail to reject H_0.')
else:
    print('Reject H_0.')
# Out:
# The number of items ordered during (3,1) is 14205.
# Of those, 7607 are reorders. The proportion of reorders is 0.5355.
# The number of items ordered during (3,0) is 28513.
# Of those, 15800 are reorders. The proportion of reorders is 0.5541.
# The difference in proportions is 0.0186.
# The margin of error is 0.01022
# The z-statistic is 3.64. and the p-value is 0.00027.
# Reject H_0.

# %% [markdown]
# Even for nearby means and small subsample sizes, the difference in reorder ratio at different times of day is significant, as long as that difference is at least roughly 0.01. Let's take a look at a difference in reorder ratios which is even smaller than that:

# %% [markdown]
# * Tuesday 1am and Tuesday 2am, i.e. $(3,1)$ and $(3,2)$
#
#
# $$
# \begin{array}{|l|c|c|}
# \hline
# & \text{(3,1)} & \text{(3,2)} \\ \hline
# \text{mean} & \hat{p}_{\text{(3,1)}} = 0.5355 & \hat{p}_{\text{(3,2)}} = 0.5434 \\ \hline
# \text{number} & n_{\text{(3,1)}} = 14205 & n_{\text{(3,2)}} = 9111 \\ \hline
# \text{reorders} & x_{\text{(3,1)}} = 7607 & x_{\text{(3,2)}} = 4951 \\ \hline
# \end{array}
# $$

# %%
mu_32, mu_31 = reorder_hour_dow.loc[3,2], reorder_hour_dow.loc[3,1]
num_32, num_31 = reorder_hour_dow_count.loc[3,2], reorder_hour_dow_count.loc[3,1]
re_32, re_31 = reorder_hour_dow_success.loc[3,2], reorder_hour_dow_success.loc[3,1]

print('The number of items ordered during (3,2) is %i.\n\
Of those, %i are reorders. The proportion of reorders is %.4f.' % (num_32, re_32, mu_32))

print('The number of items ordered during (3,1) is %i.\n\
Of those, %i are reorders. The proportion of reorders is %.4f.' % (num_31, re_31, mu_31))

print('The difference in proportions is %.4f.' % (mu_31 - mu_32))

pool = ((mu_32 * num_32) + (mu_31 * num_31)) / (num_32 + num_31)

stderr = math.sqrt(pool * (1-pool) * (1/num_32 + 1/num_31))

print('The margin of error is %.5f' % (2 * stderr))

z_stat = (mu_31 - mu_32) / stderr

p_value = 2 * stats.norm.sf(abs(z_stat)) # Two-tail
print('The z-statistic is %.2f. and the p-value is %.5f.' % (z_stat, p_value))

if p_value > alpha:
    print('Fail to reject H_0.')
else:
    print('Reject H_0.')
# Out:
# The number of items ordered during (3,2) is 9111.
# Of those, 4951 are reorders. The proportion of reorders is 0.5434.
# The number of items ordered during (3,1) is 14205.
# Of those, 7607 are reorders. The proportion of reorders is 0.5355.
# The difference in proportions is -0.0079.
# The margin of error is 0.01338
# The z-statistic is -1.18. and the p-value is 0.23812.
# Fail to reject H_0.

# %% [markdown]
# Such small differences in reorder proportions are not significant. But overall, time of day and day of week make a statistical and a possible practical difference:

# %% [markdown]
# * Tuesday 1am and Sunday 7am, i.e. $(3,1)$ and $(1,7)$:
#
#
# $$
# \begin{array}{|l|c|c|}
# \hline
# & \text{(3,1)} & \text{(1,7)} \\ \hline
# \text{mean} & \hat{p}_{\text{(3,1)}} = 0.5355 & \hat{p}_{\text{(1,7)}} = 0.6711 \\ \hline
# \text{number} & n_{\text{(3,1)}} = 14205 & n_{\text{(1,7)}} = 170880 \\ \hline
# \text{reorders} & x_{\text{(3,1)}} = 114678 & x_{\text{(1,7)}} = 4951 \\ \hline
# \end{array}
# $$

# %%
mu_31, mu_17 = reorder_hour_dow.loc[3,1], reorder_hour_dow.loc[1,7]
num_31, num_17 = reorder_hour_dow_count.loc[3,1], reorder_hour_dow_count.loc[1,7]
re_31, re_17 = reorder_hour_dow_success.loc[3,1], reorder_hour_dow_success.loc[1,7]

print('The number of items ordered during (3,1) is %i.\n\
Of those, %i are reorders. The proportion of reorders is %.4f.' % (num_31, re_31, mu_31))

print('The number of items ordered during (1,7) is %i.\n\
Of those, %i are reorders. The proportion of reorders is %.4f.' % (num_17, re_17, mu_17))

print('The difference in proportions is %.4f.' % (mu_17 - mu_31))

pool = ((mu_31 * num_31) + (mu_17 * num_17)) / (num_31 + num_17)

stderr = math.sqrt(pool * (1-pool) * (1/num_31 + 1/num_17))

print('The margin of error is %.5f' % (2 * stderr))

z_stat = (mu_17 - mu_31) / stderr

p_value = 2 * stats.norm.sf(abs(z_stat)) # Two-tail
print('The z-statistic is %.2f. and the p-value is %.5f.' % (z_stat, p_value))

if p_value > alpha:
    print('Fail to reject H_0.')
else:
    print('Reject H_0.')
# Out:
# The number of items ordered during (3,1) is 14205.
# Of those, 7607 are reorders. The proportion of reorders is 0.5355.
# The number of items ordered during (1,7) is 170880.
# Of those, 114678 are reorders. The proportion of reorders is 0.6711.
# The difference in proportions is 0.1356.
# The margin of error is 0.00827
# The z-statistic is 32.79. and the p-value is 0.00000.
# Reject H_0.

# %% [markdown]
# The above demonstrates the legitimacy of using `order_dow` and `order_hour_of_day` in our model.
